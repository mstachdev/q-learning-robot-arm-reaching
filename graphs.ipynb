# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
learning_rate = 0.5
f = "run_data_lr0_" + str(str(learning_rate)[-1:]) + ".pickle"
with open(f, 'rb') as handle:
    data0_5 = pickle.load(handle)

# %%
learning_rate = 0.7
f = "run_data_lr0_" + str(str(learning_rate)[-1:]) + ".pickle"
with open(f, 'rb') as handle:
    data0_7 = pickle.load(handle)

# %%
learning_rate = 0.9
f = "run_data_lr0_" + str(str(learning_rate)[-1:]) + ".pickle"
with open(f, 'rb') as handle:
    data0_9 = pickle.load(handle)

# %%
learning_rate = 0.925
f = "run_data_lr0_925" + ".pickle"
with open(f, 'rb') as handle:
    data0_925 = pickle.load(handle)

# %%
x = range(0, len(data0_5[0])) 
y = data0_5[0]

plt.xlabel("Episode")
plt.ylabel("Cumulative reward")
plt.title("QLearning - learning rate 0.5")
plt.ylim(-10000, 0)
plt.plot(x,y);

# %%
x = range(0, len(data0_7[0])) 
y = data0_7[0]

plt.xlabel("Episode")
plt.ylabel("Cumulative reward")
plt.title("QLearning - learning rate 0.7")
plt.ylim(-10000, 0)
plt.plot(x,y);

# %%
x = range(0, len(data0_9[0])) 
y = data0_9[0]

plt.xlabel("Episode")
plt.ylabel("Cumulative reward")
plt.title("QLearning - learning rate 0.9")
plt.ylim(-10000, 0)
plt.plot(x,y);

# %%
x = range(0, len(data0_925[0])) 
y = data0_925[0]

plt.xlabel("Episode")
plt.ylabel("Cumulative reward")
plt.title("QLearning - learning rate 0.925")
plt.ylim(-10000, 0)
plt.plot(x,y);
